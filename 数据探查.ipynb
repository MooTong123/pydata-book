# %% [markdown]
# # 数据探查（pandas框架）
#
# 1. 数据加载、存储
# 2. 数据规整：聚合、合并和重塑
# 3. 数据清洗
# 4. 数据聚合和分组运算
# 5. 时间序列处理

# %%
import numpy as np
import pandas as pd
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## 1. 数据加载和存储
#
# 读取txt、csv、json文件，数据量比较大的话pickle（pkl文件）或HDF5（h5文件）（二进制格式），可以加快系统的加载存储效率

# %% [markdown]
# ## 2. 数据规整：聚合、合并和重塑
#
# 多源数据，怎么把多表合成1个表，里面涉及到的技术就是怎么处理层次化的索引，怎么合并数据集（merge,concat函数），怎么进行重塑，轴向旋转等等

# %% [markdown]
# ### 2.1 处理层次化索引

# %%
frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
                     index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
                     columns=[['Ohio', 'Ohio', 'Colorado'],
                              ['Green', 'Red', 'Green']])
frame
# Out:
#      Ohio     Colorado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11

# %% [markdown]
# ### 2.1.1 添加轴索引名称

# %%
frame.index.names = ['key1', 'key2']
frame.columns.names = ['state', 'color']
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %% [markdown]
# ### 2.1.2 交换轴索引
# 目的：重新调整某条轴上各级别的顺序

# %%
frame.swaplevel('key1', 'key2')
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key2 key1
# 1    a        0   1        2
# 2    a        3   4        5
# 1    b        6   7        8
# 2    b        9  10       11

# %% [markdown]
# ### 2.1.3 根据轴索引排序

# %%
frame.sort_index(level = 1, axis = 0)
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
# b    1        6   7        8
# a    2        3   4        5
# b    2        9  10       11

# %%
frame.sort_index(level = 0, axis = 1)
# Out:
# state     Colorado  Ohio
# color        Green Green Red
# key1 key2
# a    1           2     0   1
#      2           5     3   4
# b    1           8     6   7
#      2          11     9  10

# %% [markdown]
# ### 2.1.4 根据级别汇总统计

# %%
frame
# Out:
# state      Ohio     Colorado
# color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11

# %%
frame.sum(level='key2')
# Out:
# state  Ohio     Colorado
# color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
frame.sum(level='color', axis=1)
# Out:
# color      Green  Red
# key1 key2
# a    1         2    1
#      2         8    4
# b    1        14    7
#      2        20   10

# %% [markdown]
# ### 2.1.5使用DataFrame的列进行索引：set_index()

# %%
frame = pd.DataFrame({'a': range(7), 'b': range(7, 0, -1),
                      'c': ['one', 'one', 'one', 'two', 'two',
                            'two', 'two'],
                      'd': [0, 1, 2, 0, 1, 2, 3]})
frame
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
frame2 = frame.set_index(['c', 'd'])
frame2
# Out:
#        a  b
# c   d
# one 0  0  7
#     1  1  6
#     2  2  5
# two 0  3  4
#     1  4  3
#     2  5  2
#     3  6  1

# %% [markdown]
# ### 2.2 合并数据集

# %% [markdown]
# ### 2.2.1 根据连接键合并数据集

# %%
left = pd.DataFrame({'key1': ['foo', 'foo', 'bar'],
                     'key2': ['one', 'two', 'one'],
                     'lval': [1, 2, 3]})
right = pd.DataFrame({'key1': ['foo', 'foo', 'bar', 'bar'],
                      'key2': ['one', 'one', 'one', 'two'],
                      'rval': [4, 5, 6, 7]})

# %%
left
# Out:
#   key1 key2  lval
# 0  foo  one     1
# 1  foo  two     2
# 2  bar  one     3

# %%
right
# Out:
#   key1 key2  rval
# 0  foo  one     4
# 1  foo  one     5
# 2  bar  one     6
# 3  bar  two     7

# %% [markdown]
# key1和key2共同为连接键，合并两表

# %%
pd.merge(left, right, on=['key1', 'key2'], how='outer')
# Out:
#   key1 key2  lval  rval
# 0  foo  one   1.0   4.0
# 1  foo  one   1.0   5.0
# 2  foo  two   2.0   NaN
# 3  bar  one   3.0   6.0
# 4  bar  two   NaN   7.0

# %% [markdown]
# ### 2.2.2 轴向连接

# %%
df1 = pd.DataFrame(np.arange(6).reshape(3, 2), index=['a', 'b', 'c'],
                   columns=['one', 'two'])
df2 = pd.DataFrame(5 + np.arange(4).reshape(2, 2), index=['a', 'c'],
                   columns=['three', 'four'])
df1
# Out:
#    one  two
# a    0    1
# b    2    3
# c    4    5

# %%
df2
# Out:
#    three  four
# a      5     6
# c      7     8

# %% [markdown]
# 列直接合并

# %%
pd.concat([df1, df2], axis=1, keys=['level1', 'level2'])
# Out:
#   level1     level2
#      one two  three four
# a      0   1    5.0  6.0
# b      2   3    NaN  NaN
# c      4   5    7.0  8.0

# %% [markdown]
# ### 2.3 重塑和轴向旋转

# %%
data = pd.read_csv('examples/macrodata.csv')
data.head()
# Out:
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
periods = pd.PeriodIndex(year=data.year, quarter=data.quarter,
                         name='date')
columns = pd.Index(['realgdp', 'infl', 'unemp'], name='item')
data = data.reindex(columns=columns)
data.index = periods.to_timestamp('D', 'end')
ldata = data.stack().reset_index().rename(columns={0: 'value'})
ldata[:10]
# Out:
#                            date     item     value
# 0 1959-03-31 23:59:59.999999999  realgdp  2710.349
# 1 1959-03-31 23:59:59.999999999     infl     0.000
# 2 1959-03-31 23:59:59.999999999    unemp     5.800
# 3 1959-06-30 23:59:59.999999999  realgdp  2778.801
# 4 1959-06-30 23:59:59.999999999     infl     2.340
# 5 1959-06-30 23:59:59.999999999    unemp     5.100
# 6 1959-09-30 23:59:59.999999999  realgdp  2775.488
# 7 1959-09-30 23:59:59.999999999     infl     2.740
# 8 1959-09-30 23:59:59.999999999    unemp     5.300
# 9 1959-12-31 23:59:59.999999999  realgdp  2785.204

# %%
pivoted = ldata.pivot('date', 'item', 'value')
pivoted
# Out:
# item                           infl    realgdp  unemp
# date
# 1959-03-31 23:59:59.999999999  0.00   2710.349    5.8
# 1959-06-30 23:59:59.999999999  2.34   2778.801    5.1
# 1959-09-30 23:59:59.999999999  2.74   2775.488    5.3
# 1959-12-31 23:59:59.999999999  0.27   2785.204    5.6
# 1960-03-31 23:59:59.999999999  2.31   2847.699    5.2
# ...                             ...        ...    ...
# 2008-09-30 23:59:59.999999999 -3.16  13324.600    6.0
# 2008-12-31 23:59:59.999999999 -8.79  13141.920    6.9
# 2009-03-31 23:59:59.999999999  0.94  12925.410    8.1
# 2009-06-30 23:59:59.999999999  3.37  12901.504    9.2
# 2009-09-30 23:59:59.999999999  3.56  12990.341    9.6
#
# [203 rows x 3 columns]

# %% [markdown]
# ## 3. 数据清洗
# 比如处理缺失数据、数据转换、字符串操作等等

# %% [markdown]
# ### 3.1 处理缺失数据

# %% [markdown]
# ### 3.2 数据转换

# %% [markdown]
# ### 3.3 字符串操作

# %% [markdown]
# ## 4. 数据聚合和分组运算
#
# 比如我们要分组统计一些平均值，标准差等等，所以我们就要对数据集进行切块、切片、摘要等操作，也可以生成一些透视表（pivot table）、交叉表（cross table）

# %% [markdown]
# ## 5. 时间序列处理
#
# 所以怎么处理时间序列，怎么分组，怎么重采样，怎么移动时间序列索引等等功能。
